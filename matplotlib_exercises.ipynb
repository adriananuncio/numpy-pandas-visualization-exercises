# %%
from matplotlib import pyplot as plt
import pandas as pd
from pydataset import data

## Data generation
import numpy as np
import random

## Mathematical functions
import math as m

## Random seed value to reproduce results
np.random.seed(123)


# Set retina for higher resolution display
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

# %% [markdown]
# ##### 1. Use matplotlib to plot the following equation:
#
# y = x^2 − x + 2
#
# You'll need to write the code that generates the x and y points.
# Add an anotation for the point 0, 0, the origin.

# %%
x = np.linspace(-10, 10, 100)
y = (x ** 2)-x+2

# %%
plt.plot(x,y)
plt.grid(color='grey', linestyle='-', linewidth='0.05')
plt.text(0,0, '(0,0)', 
          fontsize = 8 , 
          color= 'r')
# Out:
# Text(0, 0, '(0,0)')

# %% [markdown]
# ##### 2. Create and label 4 separate charts for the following equations (choose a range for x that makes sense):
# a. y = √x
#
# b. y = x^3
#
# c. y = 2^x
#
# d. y = 1/(x+1)
#
# You can use functions from the math module to help implement some of the equations above.

# %%
# a. y = √x

x = np.linspace(0, 50)
y = np.sqrt(x)

plt.plot(x,y)
plt.title('Square root of X')
plt.grid(color='grey', linestyle='-', linewidth='0.05')
plt.text(0,0, '(0,0)', 
          fontsize = 8 , 
          color= 'r')
# Out:
# Text(0, 0, '(0,0)')

# %%
# b. y = x^3

x = np.linspace(0,10)
y = x**3

plt.plot(x,y)
plt.title('X Cubed')
plt.text(0,0, '(0,0)', 
          fontsize = 8 , 
          color= 'r')
# Out:
# Text(0, 0, '(0,0)')

# %%
# c. y = 2^x

x = np.linspace(0,10)
y = 2**x

plt.plot(x,y)
plt.title('2 Squared')
plt.text(0,0, '(0,0)', 
          fontsize = 8 , 
          color= 'r')
# Out:
# Text(0, 0, '(0,0)')

# %%
# d. y = 1/(x+1)

x = np.linspace(-1,10)
x2= np.linspace(-10,-1)
y = np.reciprocal(x+1)
y2= np.reciprocal(x2+1)

plt.plot(x,y, 'b')
plt.plot(x2,y2, 'b')
plt.title('Reciprocal Function')
plt.text(0,0, '(0,0)', 
          fontsize = 8 , 
          color= 'r')
# Out:
# /var/folders/cf/g2l7s99s5qbdrr9dn3j5vff40000gn/T/ipykernel_16986/2167276666.py:5: RuntimeWarning: divide by zero encountered in reciprocal
#   y = np.reciprocal(x+1)
# /var/folders/cf/g2l7s99s5qbdrr9dn3j5vff40000gn/T/ipykernel_16986/2167276666.py:6: RuntimeWarning: divide by zero encountered in reciprocal
#   y2= np.reciprocal(x2+1)
# Text(0, 0, '(0,0)')
