# %%
# imports

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris = sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# 1. What does the distribution of petal lengths look like?
# Distibution of petal lengths is right skewed

petal_len_dist = sns.displot(data=iris, x='petal_length')

petal_len_dist

# %%
# 2. Is there a correlation between petal length and petal width?
# There is a strong positive correlation between petal length and petal width

sns.relplot(data=iris, x='petal_length', y='petal_width')
plt.show()

# %%
# 3. Would it be reasonable to predict species based on 
# sepal width and sepal length? For this, you'll visualize 
# two numeric columns through the lense of a categorical column.
plt.suptitle('Sepal length and width by species')

plt.subplot(121)
sns.boxplot(data=iris, x='species', y='sepal_length')
plt.title('Sepal length by species')

plt.subplot(122)
sns.boxplot(data=iris, x='species', y='sepal_width')
plt.title('Sepal width by species')

plt.show()

# %%
# It would not be a good idea to predict species based 
# on sepal length and sepal width because there is 
# not a significant difference in their values.

# %%
# 4. Which features would be best used to predict species?
sns.heatmap(iris.corr(),
    annot=True,
    cmap='coolwarm',
    vmax=1,
    vmin=-1,
    center=0,
    linewidth=1,
    linecolor='k',
    fmt='.2f')

plt.show()

# %%
iris.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.pairplot(iris, corner = True)
plt.show()

# %%
plt.suptitle('Petal length and width by species')

plt.subplot(121)
sns.boxplot(data=iris, x='species', y='petal_length')
plt.title('Petal length by species')

plt.subplot(122)
sns.boxplot(data=iris, x='species', y='petal_width')
plt.title('Petal width by species')

plt.show()

# %%
# petal length and width would be better features to 
# make species predictions with because there is a strong 
# positive corrilation indicated by the 0.96 correlation value 
# and their box plots show a more significant difference in values

# %% [markdown]
# #####

# %%
# 1. Using the lesson as an example, use seaborn's load_dataset
# function to load the anscombe data set. Use pandas to group 
# the data by the dataset column, and calculate summary 
# statistics for each dataset. What do you notice?
df = sns.load_dataset('anscombe')

df.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
groups = df.groupby(['dataset'])

# %%
groups.describe()
# Out:
#             x                                               y            \
#         count mean       std  min  25%  50%   75%   max count      mean
# dataset
# I        11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# II       11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# III      11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500000
# IV       11.0  9.0  3.316625  8.0  8.0  8.0   8.0  19.0  11.0  7.500909
#
#
#               std   min    25%   50%   75%    max
# dataset
# I        2.031568  4.26  6.315  7.58  8.57  10.84
# II       2.031657  3.10  6.695  8.14  8.95   9.26
# III      2.030424  5.39  6.250  7.11  7.98  12.74
# IV       2.030579  5.25  6.170  7.04  8.19  12.50

# %%
# the values across datasets is identical, if not similar.

# %%
# 1a. Plot the x and y values from the anscombe data. 
# Each dataset should be in a separate column.
sns.relplot(data=df, x='x', y='y')
plt.show()

# %%
# 2. Load the InsectSprays dataset and read it's documentation.
# Create a boxplot that shows the effectiveness of the 
# different insect sprays.
from pydataset import data

df = data('InsectSprays')

df.head()
# Out:
#    count spray
# 1     10     A
# 2      7     A
# 3     20     A
# 4     14     A
# 5     14     A

# %%
box_plot = sns.boxplot(data=df, x='spray', y='count')
plt.show()

# %%
# 3. Load the swiss dataset and read it's documentation. 
# The swiss dataset is available from pydatset rather than 
# seaborn. Create visualizations to answer the following 
# questions:

from pydataset import data

df = data('swiss')

df.head()
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Courtelary         80.2         17.0           15         12      9.96
# Delemont           83.1         45.1            6          9     84.84
# Franches-Mnt       92.5         39.7            5          5     93.40
# Moutier            85.8         36.5           12          7     33.77
# Neuveville         76.9         43.5           17         15      5.16
#
#               Infant.Mortality
# Courtelary                22.2
# Delemont                  22.2
# Franches-Mnt              20.2
# Moutier                   20.3
# Neuveville                20.6

# %%
# 3a. Create an attribute named is_catholic that holds a 
# boolean value of whether or not the province is Catholic. 
# (Choose a cutoff point for what constitutes catholic)

df['is_catholic'] = np.where(df.Catholic >= 70.00, 1, 0)

# %%
df.head()
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Courtelary         80.2         17.0           15         12      9.96
# Delemont           83.1         45.1            6          9     84.84
# Franches-Mnt       92.5         39.7            5          5     93.40
# Moutier            85.8         36.5           12          7     33.77
# Neuveville         76.9         43.5           17         15      5.16
#
#               Infant.Mortality  is_catholic
# Courtelary                22.2            0
# Delemont                  22.2            1
# Franches-Mnt              20.2            1
# Moutier                   20.3            0
# Neuveville                20.6            0

# %%
# 3b. Does whether or not a province is Catholic influence 
# fertility?
sns.boxplot(data=df, x='is_catholic', y='Fertility')
plt.show()

df.corr()
# 0 = not catholic, 1 = catholic
# Out:
#                   Fertility  Agriculture  Examination  Education  Catholic  \
# Fertility          1.000000     0.353079    -0.645883  -0.663789  0.463685
# Agriculture        0.353079     1.000000    -0.686542  -0.639523  0.401095
# Examination       -0.645883    -0.686542     1.000000   0.698415 -0.572742
# Education         -0.663789    -0.639523     0.698415   1.000000 -0.153859
# Catholic           0.463685     0.401095    -0.572742  -0.153859  1.000000
# Infant.Mortality   0.416556    -0.060859    -0.114022  -0.099322  0.175496
# is_catholic        0.605023     0.475120    -0.641897  -0.328808  0.957798
#
#                   Infant.Mortality  is_catholic
# Fertility                 0.416556     0.605023
# Agriculture              -0.060859     0.475120
# Examination              -0.114022    -0.641897
# Education                -0.099322    -0.328808
# Catholic                  0.175496     0.957798
# Infant.Mortality          1.000000     0.207544
# ...

# %% [markdown]
# ##### The correlation value, 0.605, indicats a slight linear correlation between being catholic and fertility. The box plots show significant overlap however, suggesting no correlation.

# %%
# 3c. What measure correlates most strongly with fertility?

sns.heatmap(df.corr(),
           annot=True,
           cmap='coolwarm',
           vmax=1,
           vmin=-1,
           center=0,
           linewidth=1,
           linecolor='k',
           fmt='.2f')
plt.show()

# %% [markdown]
# ##### Education most strongly correlates to fertility. It is a negative correlation, slightly linear.

# %%
# 4. Using the chipotle dataset from the previous exercise, 
# create a bar chart that shows the 4 most popular items and 
# the revenue produced by each.

def get_db_url(db):
    from env import user, password, host
    return f'mysql+pymysql://{user}:{password}@{host}/{db}'

# %%
url = get_db_url('chipotle')

query = "SELECT * FROM orders"

orders = pd.read_sql(query, url)

orders.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 url = get_db_url('chipotle')
#       3 query = "SELECT * FROM orders"
#       5 orders = pd.read_sql(query, url)
#
# Input In [11], in get_db_url(db)
#       5 def get_db_url(db):
# ----> 6     from env import user, password, host
#       7     return f'mysql+pymysql://{user}:{password}@{host}/{db}'
#
# ModuleNotFoundError: No module named 'env'

# %%
# 5. Load the sleepstudy data and read it's documentation. 
# Use seaborn to create a line chart of all the individual 
# subject's reaction times and a more prominant line showing 
# the average change in reaction time.

# %% [markdown]
# #####
